# %% [markdown]
# # Reproducible worm-species manuscript figures
#
# This notebook is a thin interface to the completed-run report builder. It contains no embedded results. The builder recreates the baseline, visual-ablation, interaction, structured-holdout, resolution-control, and confusion-matrix figure families; writes PNG, PDF, and SVG; and stores the exact CSV and image inputs under `paper_result/figure_sources/`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

from scripts.build_paper_results import build_report

summary = build_report(
    PROJECT_ROOT / "paper_result",
    split_root=PROJECT_ROOT,
    style_path=PROJECT_ROOT / "dev" / "paper_report_style.yaml",
)
summary

# %%
from IPython.display import display, Image as DisplayImage

figure_dir = PROJECT_ROOT / "paper_result" / "figures"
for path in sorted(figure_dir.glob("*.png")):
    print(path.name)
    display(DisplayImage(filename=str(path)))

# %%
source_root = PROJECT_ROOT / "paper_result" / "figure_sources"
audit = {
    directory.name: sorted(path.name for path in directory.iterdir())
    for directory in sorted(source_root.iterdir())
    if directory.is_dir()
}
audit
